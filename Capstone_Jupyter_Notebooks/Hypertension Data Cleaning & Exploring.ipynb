# %%
import pandas as pd

# %%
hypertension_data =pd.read_csv('Hypertension.csv')

# %%
hypertension_data.head(5)
# Out:
#   Country/Region/World  ISO  Sex  Year                             Age  \
# 0          Afghanistan  AFG  Men  1990  Age standardised (30-79 years)
# 1          Afghanistan  AFG  Men  1991  Age standardised (30-79 years)
# 2          Afghanistan  AFG  Men  1992  Age standardised (30-79 years)
# 3          Afghanistan  AFG  Men  1993  Age standardised (30-79 years)
# 4          Afghanistan  AFG  Men  1994  Age standardised (30-79 years)
#
#    Prevalence of hypertension  \
# 0                    0.331843
# 1                    0.332705
# 2                    0.333643
# 3                    0.334619
# 4                    0.335512
#
#    Prevalence of hypertension lower 95% uncertainty interval  \
# 0                                           0.190057
# 1                                           0.196482
# 2                                           0.202168
# 3                                           0.209102
# 4                                           0.214306
#
#    Prevalence of hypertension upper 95% uncertainty interval  \
# 0                                           0.495322
# 1                                           0.487221
# 2                                           0.481609
# 3                                           0.476224
# 4                                           0.472759
#
#    Proportion of diagnosed hypertension among all hypertension  \
# 0                                           0.217042
# 1                                           0.222470
# 2                                           0.228117
# 3                                           0.233977
# 4                                           0.239990
#
#    Proportion of diagnosed hypertension among all hypertension lower 95% uncertainty interval  \
# 0                                           0.080527
# 1                                           0.086410
# 2                                           0.092876
# 3                                           0.099647
# 4                                           0.107187
#
#    Proportion of diagnosed hypertension among all hypertension upper 95% uncertainty interval  \
# 0                                           0.416364
# 1                                           0.414061
# 2                                           0.415406
# 3                                           0.416563
# 4                                           0.418237
#
#    Proportion of treated hypertension among all hypertension  \
# 0                                           0.137442
# 1                                           0.142342
# 2                                           0.147571
# 3                                           0.153131
# 4                                           0.159044
#
#    Proportion of treated hypertension among all hypertension lower 95% uncertainty interval  \
# 0                                           0.030317
# 1                                           0.034584
# 2                                           0.039084
# 3                                           0.043954
# 4                                           0.049133
#
#    Proportion of treated hypertension among all hypertension upper 95% uncertainty interval  \
# 0                                           0.316249
# 1                                           0.318273
# 2                                           0.319533
# 3                                           0.320049
# 4                                           0.324701
#
#    Proportion of controlled hypertension among all hypertension  \
# 0                                           0.026010
# 1                                           0.026776
# 2                                           0.027751
# 3                                           0.028945
# 4                                           0.030371
#
#    Proportion of controlled hypertension among all hypertension lower 95% uncertainty interval  \
# 0                                           0.001348
# 1                                           0.001727
# 2                                           0.002184
# 3                                           0.002624
# 4                                           0.003202
#
#    Proportion of controlled hypertension among all hypertension upper 95% uncertainty interval  \
# 0                                           0.105405
# 1                                           0.102808
# 2                                           0.101488
# 3                                           0.099899
# 4                                           0.100960
#
#    Proportion of untreated stage 2 hypertension among all hypertension  \
# 0                                           0.325092
# 1                                           0.319920
# 2                                           0.314806
# 3                                           0.309792
# 4                                           0.304867
#
#    Proportion of untreated stage 2 hypertension among all hypertension lower 95% uncertainty interval  \
# 0                                           0.169098
# 1                                           0.171497
# 2                                           0.172962
# 3                                           0.173026
# 4                                           0.174121
#
#    Proportion of untreated stage 2 hypertension among all hypertension upper 95% uncertainty interval
# 0                                           0.500993
# 1                                           0.483893
# 2                                           0.470403
# 3                                           0.457284
# 4                                           0.445977

# %%
# Dropping columns
hypertension_data.drop(columns=['Prevalence of hypertension lower 95% uncertainty interval',
                               'Prevalence of hypertension upper 95% uncertainty interval',
                               'Proportion of diagnosed hypertension among all hypertension lower 95% uncertainty interval',
                               'Proportion of diagnosed hypertension among all hypertension upper 95% uncertainty interval',
                               'Proportion of treated hypertension among all hypertension lower 95% uncertainty interval',
                               'Proportion of treated hypertension among all hypertension upper 95% uncertainty interval',
                               'Proportion of controlled hypertension among all hypertension lower 95% uncertainty interval',
                               'Proportion of controlled hypertension among all hypertension upper 95% uncertainty interval',
                               'Proportion of untreated stage 2 hypertension among all hypertension lower 95% uncertainty interval',
                               'Proportion of untreated stage 2 hypertension among all hypertension upper 95% uncertainty interval'],
                      inplace=True)

# %%
hypertension_data.head(5)
# Out:
#   Country/Region/World  ISO  Sex  Year                             Age  \
# 0          Afghanistan  AFG  Men  1990  Age standardised (30-79 years)
# 1          Afghanistan  AFG  Men  1991  Age standardised (30-79 years)
# 2          Afghanistan  AFG  Men  1992  Age standardised (30-79 years)
# 3          Afghanistan  AFG  Men  1993  Age standardised (30-79 years)
# 4          Afghanistan  AFG  Men  1994  Age standardised (30-79 years)
#
#    Prevalence of hypertension  \
# 0                    0.331843
# 1                    0.332705
# 2                    0.333643
# 3                    0.334619
# 4                    0.335512
#
#    Proportion of diagnosed hypertension among all hypertension  \
# 0                                           0.217042
# 1                                           0.222470
# 2                                           0.228117
# 3                                           0.233977
# 4                                           0.239990
#
#    Proportion of treated hypertension among all hypertension  \
# 0                                           0.137442
# 1                                           0.142342
# 2                                           0.147571
# 3                                           0.153131
# 4                                           0.159044
#
#    Proportion of controlled hypertension among all hypertension  \
# 0                                           0.026010
# 1                                           0.026776
# 2                                           0.027751
# 3                                           0.028945
# 4                                           0.030371
#
#    Proportion of untreated stage 2 hypertension among all hypertension
# 0                                           0.325092
# 1                                           0.319920
# 2                                           0.314806
# 3                                           0.309792
# 4                                           0.304867

# %%
hypertension_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12000 entries, 0 to 11999
# Data columns (total 10 columns):
#  #   Column                                                               Non-Null Count  Dtype
# ---  ------                                                               --------------  -----
#  0   Country/Region/World                                                 12000 non-null  object
#  1   ISO                                                                  12000 non-null  object
#  2   Sex                                                                  12000 non-null  object
#  3   Year                                                                 12000 non-null  int64
#  4   Age                                                                  12000 non-null  object
#  5   Prevalence of hypertension                                           12000 non-null  float64
#  6   Proportion of diagnosed hypertension among all hypertension          12000 non-null  float64
#  7   Proportion of treated hypertension among all hypertension            12000 non-null  float64
#  8   Proportion of controlled hypertension among all hypertension         12000 non-null  float64
#  9   Proportion of untreated stage 2 hypertension among all hypertension  12000 non-null  float64
# dtypes: float64(5), int64(1), object(4)
# memory usage: 937.6+ KB

# %%
hypertension_data.shape
# Out:
# (12000, 10)

# %%
hypertension_data.isnull().sum()
# Out:
# Country/Region/World                                                   0
# ISO                                                                    0
# Sex                                                                    0
# Year                                                                   0
# Age                                                                    0
# Prevalence of hypertension                                             0
# Proportion of diagnosed hypertension among all hypertension            0
# Proportion of treated hypertension among all hypertension              0
# Proportion of controlled hypertension among all hypertension           0
# Proportion of untreated stage 2 hypertension among all hypertension    0
# dtype: int64

# %%
hypertension_data.boxplot(column='Prevalence of hypertension')
# Out:
# <AxesSubplot:>

# %%
hypertension_data.groupby('Sex').boxplot(column='Prevalence of hypertension')
# Out:
# Men           AxesSubplot(0.1,0.15;0.363636x0.75)
# Women    AxesSubplot(0.536364,0.15;0.363636x0.75)
# dtype: object

# %%
hypertension_data.to_csv (r'.\Cleaned_Hypertension_Data.csv', index = False, header=True)
