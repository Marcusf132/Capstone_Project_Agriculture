# %%
import pandas as pd

# %%
Food=pd.read_csv('FoodBalanceSheets_E_All_Data_(Normalized).csv',engine='python',encoding='latin1')

# %%
Food.head(5)
# Out:
#    Area Code         Area  Item Code        Item  Element Code  \
# 0          2  Afghanistan       2501  Population           511
# 1          2  Afghanistan       2501  Population           511
# 2          2  Afghanistan       2501  Population           511
# 3          2  Afghanistan       2501  Population           511
# 4          2  Afghanistan       2501  Population           511
#
#                          Element  Year Code  Year          Unit    Value Flag
# 0  Total Population - Both sexes       2010  2010  1000 persons  29186.0    *
# 1  Total Population - Both sexes       2011  2011  1000 persons  30117.0    *
# 2  Total Population - Both sexes       2012  2012  1000 persons  31161.0    *
# 3  Total Population - Both sexes       2013  2013  1000 persons  32270.0    *
# 4  Total Population - Both sexes       2014  2014  1000 persons  33371.0    *

# %%
Food.isnull().sum()
# Out:
# Area Code           0
# Area                0
# Item Code           0
# Item                0
# Element Code        0
# Element             0
# Year Code           0
# Year                0
# Unit                0
# Value           63553
# Flag                0
# dtype: int64

# %%
Food.shape
# Out:
# (2975297, 11)

# %%
Food.groupby(['Element']).mean()
# Out:
#                                           Area Code    Item Code  \
# Element
# Domestic supply quantity                 972.797488  2682.202783
# Export Quantity                         1114.009175  2693.463156
# Fat supply quantity (g/capita/day)      1020.760934  2697.827496
# Feed                                    1360.200947  2710.291620
# Food                                    1017.981977  2691.503037
# Food supply (kcal/capita/day)           1021.961518  2697.848126
# Food supply quantity (kg/capita/yr)     1019.364987  2691.119717
# Import Quantity                         1002.467042  2686.869777
# Losses                                  1293.624425  2702.958846
# Other uses (non-food)                   1483.969285  2740.206794
# Processing                              1525.923517  2701.185628
# Production                              1185.722051  2701.259497
# Protein supply quantity (g/capita/day)  1020.845402  2697.835046
# ...

# %%
# Drop Null Values from 'Value' column
Food.dropna(inplace=True)

# %%
Food.isnull().sum()
# Out:
# Area Code       0
# Area            0
# Item Code       0
# Item            0
# Element Code    0
# Element         0
# Year Code       0
# Year            0
# Unit            0
# Value           0
# Flag            0
# dtype: int64

# %%
Food.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2911744 entries, 0 to 2975296
# Data columns (total 11 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   Area Code     int64
#  1   Area          object
#  2   Item Code     int64
#  3   Item          object
#  4   Element Code  int64
#  5   Element       object
#  6   Year Code     int64
#  7   Year          int64
#  8   Unit          object
#  9   Value         float64
#  10  Flag          object
# dtypes: float64(1), int64(5), object(5)
# memory usage: 266.6+ MB

# %%
Food.groupby(['Area']).mean()
# Out:
#                 Area Code    Item Code  Element Code    Year Code  \
# Area
# Afghanistan           2.0  2698.318375   3880.066672  2014.494976
# Africa             5100.0  2681.888908   4067.140899  2014.490102
# Albania               3.0  2701.371526   3848.469305  2014.440879
# Algeria               4.0  2697.769394   3814.127954  2014.440164
# Americas           5200.0  2681.730399   4094.845543  2014.494408
# ...                   ...          ...           ...          ...
# Western Europe     5404.0  2687.125279   4001.287357  2014.398582
# World              5000.0  2680.415048   4121.326301  2014.493515
# Yemen               249.0  2696.937644   3844.232122  2014.333333
# Zambia              251.0  2695.292590   3871.091408  2014.386813
# Zimbabwe            181.0  2694.372245   3861.034570  2014.408012
#
#                        Year         Value
# Area
# Afghanistan     2014.494976    124.868424
# Africa          2014.490102   4394.294708
# ...

# %%
Food.groupby(['Item', 'Area']).mean()
# Out:
#                                   Area Code  Item Code  Element Code  \
# Item              Area
# Alcohol, Non-Food Afghanistan           2.0     2659.0   5441.277778
#                   Africa             5100.0     2659.0   5024.658537
#                   Albania               3.0     2659.0   5297.021277
#                   Algeria               4.0     2659.0   5328.720000
#                   Americas           5200.0     2659.0   5390.000000
# ...                                     ...        ...           ...
# Yams              Western Europe     5404.0     2535.0   3786.529412
#                   World              5000.0     2535.0   4180.062500
#                   Yemen               249.0     2535.0   5301.000000
#                   Zambia              251.0     2535.0   5405.384615
#                   Zimbabwe            181.0     2535.0   5301.000000
#
#                                     Year Code         Year         Value
# Item              Area
# ...

# %%
Food.groupby(['Item', 'Area']).max('Value')
# Out:
#                                   Area Code  Item Code  Element Code  \
# Item              Area
# Alcohol, Non-Food Afghanistan             2       2659          5911
#                   Africa               5100       2659          5911
#                   Albania                 3       2659          5911
#                   Algeria                 4       2659          5911
#                   Americas             5200       2659          5911
# ...                                     ...        ...           ...
# Yams              Western Europe       5404       2535          5911
#                   World                5000       2535          5911
#                   Yemen                 249       2535          5301
#                   Zambia                251       2535          5911
#                   Zimbabwe              181       2535          5301
#
#                                   Year Code  Year    Value
# Item              Area
# ...

# %%
Food.drop(columns='Year Code', inplace=True)

# %%
Food.drop(columns='Flag', inplace=True)

# %%
# Save cleaned data to CSV file
Food.to_csv (r'.\Cleaned_Supply_Utilisation.csv', index = False, header=True)
