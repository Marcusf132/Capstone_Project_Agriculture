# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
aus_data = pd.read_csv('Supply_Utilisation_Australia.csv')

# %%
aus_data.head(5)
# Out:
#     index  Area Code       Area  Item Code  Item  Element Code  \
# 0  100187         10  Australia       2949  Eggs          5123
# 1  100188         10  Australia       2949  Eggs          5123
# 2  100189         10  Australia       2949  Eggs          5154
# 3  100190         10  Australia       2949  Eggs          5154
# 4  100191         10  Australia       2949  Eggs          5154
#
#                  Element  Year         Unit  Value
# 0                 Losses  2018  1000 tonnes    3.0
# 1                 Losses  2019  1000 tonnes    3.0
# 2  Other uses (non-food)  2010  1000 tonnes    0.0
# 3  Other uses (non-food)  2011  1000 tonnes    0.0
# 4  Other uses (non-food)  2012  1000 tonnes    0.0

# %%
aus_data.shape
# Out:
# (14047, 10)

# %%
pd.set_option('display.max_rows', None)
aus_data.groupby('Item').describe()
# Out:
#                                  index                                  \
#                                  count      mean         std       min
# Item
# Alcohol, Non-Food                 66.0   98357.5   19.196354   98325.0
# Alcoholic Beverages              130.0   97799.5   37.671829   97735.0
# Animal Products                   30.0   88218.5    8.803408   88204.0
# Animal fats                      150.0   99459.5   43.445368   99385.0
# Apples and products              120.0   96212.5   34.785054   96153.0
# Aquatic Animals, Others          100.0  101720.5   29.011492  101671.0
# Aquatic Plants                   100.0  101820.5   29.011492  101771.0
# Aquatic Products, Other          100.0  101620.5   29.011492  101571.0
# Bananas                          130.0   95997.5   37.671829   95933.0
# Barley and products              150.0   88788.5   43.445368   88714.0
# Beans                            136.0   91389.5   39.403892   91322.0
# ...
